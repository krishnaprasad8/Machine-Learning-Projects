# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Life Expectancy Data.csv')

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df['Population'].isna().sum()
# Out:
# 652

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
sns.jointplot('Measles ','Life expectancy ',data=df)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Schooling',y='Life expectancy ',data=df)

# %%
corr=df.corr()
plt.figure(figsize=(15,6))
sns.heatmap(corr,cmap="YlGnBu")

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Country',y='Life expectancy ',data=df)

# %%
plt.scatter(df['Total expenditure'],df['Life expectancy '])

# %%
mean_am=df['Adult Mortality']=df['Adult Mortality'].mean()

# %%
df['Adult Mortality'].replace(np.nan,mean_am,inplace=True)

# %%
mean_bmi=df[' BMI '].mean()

# %%
df[' BMI '].replace(np.nan,mean_bmi,inplace=True)

# %%
mean_a=df['Alcohol'].mean()

# %%
df['Alcohol'].replace(np.nan,mean_a,inplace=True)

# %%
mean_h=df['Hepatitis B'].mean()
df['Hepatitis B'].replace(np.nan,mean_h,inplace=True)

# %%
mean_p=df['Polio'].mean()
df['Polio'].replace(np.nan,mean_p,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                              0
# percentage expenditure               0
# Hepatitis B                          0
# Measles                              0
#  BMI                                 0
# under-five deaths                    0
# Polio                                0
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
mean_te=df['Total expenditure'].mean()

# %%
df['Total expenditure'].replace(np.nan,mean_te,inplace=True)

# %%
mean_D=df['Diphtheria '].mean()

# %%
df['Diphtheria '].replace(np.nan,mean_D,inplace=True)

# %%
mean_G=df['GDP'].mean()
df['GDP'].replace(np.nan,mean_G,inplace=True)

# %%
mean_P=df['Population'].mean()
df['Population'].replace(np.nan,mean_P,inplace=True)

# %%
mean_t1=df[' thinness  1-19 years'].mean()
df[' thinness  1-19 years'].replace(np.nan,mean_t1,inplace=True)

# %%
mean_t2=df[' thinness 5-9 years'].mean()
df[' thinness 5-9 years'].replace(np.nan,mean_t2,inplace=True)

# %%
df[' thinness 5-9 years'].isna().sum()
# Out:
# 0

# %%
mean_inc=df['Income composition of resources'].mean()

# %%
df['Income composition of resources'].replace(np.nan,mean_inc,inplace=True)

# %%
df['Schooling'].isnull().sum()
# Out:
# 163

# %%
mean_s=df['Schooling'].mean()
df['Schooling'].replace(np.nan,mean_s,inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                             0
# Year                                0
# Status                              0
# Life expectancy                    10
# Adult Mortality                     0
# infant deaths                       0
# Alcohol                             0
# percentage expenditure              0
# Hepatitis B                         0
# Measles                             0
#  BMI                                0
# under-five deaths                   0
# Polio                               0
# Total expenditure                   0
# Diphtheria                          0
#  HIV/AIDS                           0
# GDP                                 0
# Population                          0
#  thinness  1-19 years               0
#  thinness 5-9 years                 0
# Income composition of resources     0
# Schooling                           0
# dtype: int64

# %%
df['Life expectancy '].isnull().value_counts()
# Out:
# False    2928
# True       10
# Name: Life expectancy , dtype: int64

# %%
mean_le=df['Life expectancy '].mean()
df['Life expectancy '].replace(np.nan,mean_le,inplace=True)

# %%
df[' thinness 5-9 years'].isnull().value_counts()
# Out:
# False    2938
# Name:  thinness 5-9 years, dtype: int64

# %%
col=['Status']

# %%
df=pd.get_dummies(df,columns=col,drop_first=True)

# %%
df['Status_Developing']=df['Status_Developing'].astype('int')

# %% [markdown]
# df.dtypes

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Status_Developing'],
#       dtype='object')

# %%
sns.distplot(df['Life expectancy '],bins=50)

# %%
sns.lmplot(x='Alcohol',y='Life expectancy ',data=df)

# %%
X=df.drop(['Life expectancy ','Country'],axis=1)

# %%
y=df['Life expectancy ']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df['Life expectancy '].value_counts()
# Out:
# 73.0    45
# 75.0    33
# 78.0    31
# 73.6    28
# 73.9    25
#         ..
# 36.3     1
# 83.1     1
# 49.5     1
# 44.0     1
# 43.1     1
# Name: Life expectancy , Length: 363, dtype: int64

# %%
predictions=lr.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print(r2_score(y_test,predictions))
# Out:
# 0.7823190706528512

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 3.2795356600067045

# %%
mean_squared_error(y_test,predictions)
# Out:
# 19.999211185502272
